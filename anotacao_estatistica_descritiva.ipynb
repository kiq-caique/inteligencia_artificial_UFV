# %% [markdown]
# <a href="https://colab.research.google.com/github/kiq-caique/inteligencia_artificial_UFV/blob/main/anotacao_estatistica_descritiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GRAFICOS EM PYTHON COM MATPLOIT

# %% [markdown]
# # COLUNAS / BARRAS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y= [2, 5, 2, 7,5,1]

x= ['N1','N2','N3','N4','N5','N6']

x2= ['Variável um','Variável dois','Variável três','Variável quatro','Variável cinco','Variável seis']

# %% [markdown]
# Plotando

# %%
plt.barh(x2,y, color='g')
plt.xlabel("Titulo eixo X", size=24)
plt.ylabel("Titulo eixo Y", size=20)
plt.title("Titulo do meu gráfico")
# Out:
# Text(0.5, 1.0, 'Titulo do meu gráfico')

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Seaborn

# %%
sns.barplot(x=x,y=y)
# Out:
# <Axes: >

# %% [markdown]
# # SETORES

# %%
plt.pie(y,labels=x, radius=2)
plt.show()

# %% [markdown]
# # LINHAS

# %%
y = [6,8,3,1,9]

x1= [1,2,3,4,5]

x= ['seg', 'ter', 'qua', 'qui', 'sex']

# %%
plt.plot(x1,y, '*-g')
plt.xlabel('Eixo X', size=20)
plt.ylabel('Eixo Y', size=20)
plt.title('Título do gráfico',size=15)
plt.show()

# %% [markdown]
# # HISTOGRAMA

# %%
import numpy as np

# %%
x = np.random.randn(1000)

# %%
plt.hist(x)
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
# Out:
# Text(0, 0.5, 'Eixo Y')

# %% [markdown]
# # MÉDIA, MEDIANA e MODA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bokeh.sampledata.iris import flowers as dados

# %%
dados.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %% [markdown]
# **Cálculo da Média**

# %%
med_sl = np.mean(dados['sepal_length'])
# med_sl = np.mean(dados.iloc[:, 0])
med_sl
# Out:
# 5.843333333333334

# %%
dados_numericos = dados.select_dtypes(include=[np.number])
med = dados_numericos.mean()

med
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %% [markdown]
# **Calculo da Mediana**

# %%
mediana_sl = np.median(dados['sepal_length'])
mediana_sl
# Out:
# 5.8

# %%
mediana_sw = np.median(dados['sepal_width'])
mediana_sw
# Out:
# 3.0

# %%
mediana_pl = np.median(dados['petal_length'])
mediana_pl
# Out:
# 4.35

# %%
mediana_pw = np.median(dados['petal_width'])
mediana_pw
# Out:
# 1.3

# %% [markdown]
# **Cálcula da Moda**

# %%
modal_sl = dados['sepal_length'].mode()
modal_sl
# Out:
# 0    5.0
# Name: sepal_length, dtype: float64

# %%
modal_sw = dados['sepal_width'].mode()
modal_sw
# Out:
# 0    3.0
# Name: sepal_width, dtype: float64

# %%
mediana_pl = dados['petal_length'].mode()
mediana_pl
# Out:
# 0    1.4
# 1    1.5
# Name: petal_length, dtype: float64

# %%
mediana_pw = dados['petal_width'].mode()
mediana_pw
# Out:
# 0    0.2
# Name: petal_width, dtype: float64

# %% [markdown]
# # SEPARATRIZES

# %%
P10 = np.quantile(dados['sepal_length'], 0.10)
P10
# Out:
# 4.8

# %%
P50 = np.quantile(dados['sepal_length'], 0.50)
P50
# Out:
# 5.8

# %%
Q1 = np.quantile(dados['sepal_length'], 0.25)
Q1
# Out:
# 5.1

# %%
Q3 = np.quantile(dados['sepal_length'], 0.75)
Q3
# Out:
# 6.4

# %% [markdown]
# # INFORMAÇÕES CONDENSADAS

# %% [markdown]
# **quantidades de dados, média, desvio padão, valor mín, Percentil 25/1ºQuantil, 2ºQuantil/Mediana, 3ºQuantil, valor máx **

# %%
dados.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dados.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %% [markdown]
# # VISÃO ESPACIAL DAS ESTATÍSTICAS DESCRITIVAS

# %% [markdown]
# **Sepala**

# %%
x= dados['sepal_length']
y= dados['sepal_width']

# %%
plt.scatter(x,y)
plt.xlabel("sepal_lengt", size= 20)
plt.ylabel("sepal_width", size= 20)
mean_x = np.mean(x)
mean_y = np.mean(y)



# Desenhar o ponto da MÉDIA dentro do espaço amostral
plt.plot(np.mean(x),np.mean(y),marker='o', color='red',linestyle=':')
# Desenhar linha vertical da média até o eixo x
plt.plot([mean_x, mean_x], [np.min(y), mean_y], linestyle=':', color='red')
# Desenhar linha horizontal da média até o eixo y
plt.plot([np.min(x), mean_x], [mean_y, mean_y], linestyle=':', color='red')
# Desenhar linha diagonal da média até os mínimos do espaço amostral
plt.plot([np.min(x), mean_x], [np.min(y), mean_y], linestyle=':', color='red')


# Desenhar o ponto da MEDIANA dentro do espaço amostral
plt.plot(np.median(x),np.median(y),marker='o', color='purple')
plt.plot([np.min(x), np.median(x)], [np.median(y), np.median(y)], linestyle=':', color='purple')
plt.plot([np.median(x), np.median(x)], [np.median(y), np.min(y)], linestyle=':', color='purple')


# Calcular a MODA
modal_sl = dados['sepal_length'].mode().iloc[0]
modal_sw = dados['sepal_width'].mode().iloc[0]

mode_x = modal_sl
mode_y = modal_sw

plt.plot(mode_x, mode_y, marker='o', color='green')
plt.plot(mode_x, mode_y, marker='o', color='green')
plt.plot([np.min(x), mode_x], [mode_y, mode_y], linestyle=':', color='green')
plt.plot([mode_x, mode_x], [np.min(y), mode_y], linestyle=':', color='green')

plt.show()

# %% [markdown]
# **Pétala**

# %%
x2= dados['petal_length']
y2= dados['petal_width']

plt.scatter(x2,y2)
plt.xlabel("petal_length", size= 20)
plt.ylabel("petal_width", size= 20)

mean_x2 = np.mean(x2)
mean_y2 = np.mean(y2)

# Desenhar o ponto da MÉDIA dentro do espaço amostral
plt.plot(np.mean(x2),np.mean(y2),marker='o', color='red',linestyle=':')
# Desenhar linha vertical da média até o eixo x
plt.plot([mean_x2, mean_x2], [np.min(y2), mean_y2], linestyle=':', color='red')
# Desenhar linha horizontal da média até o eixo y
plt.plot([np.min(x2), mean_x2], [mean_y2, mean_y2], linestyle=':', color='red')
# Desenhar linha diagonal da média até os mínimos do espaço amostral
plt.plot([np.min(x2), mean_x2], [np.min(y2), mean_y2], linestyle=':', color='red')


# Desenhar o ponto da MEDIANA dentro do espaço amostral
plt.plot(np.median(x2),np.median(y2),marker='o', color='purple')
plt.plot([np.min(x2), np.median(x2)], [np.median(y2), np.median(y2)], linestyle=':', color='purple')
plt.plot([np.median(x2), np.median(x2)], [np.median(y2), np.min(y2)], linestyle=':', color='purple')


# # Calcular a MODA, porém no caso da PÉTALAS, EXISTEM 2 MODAS.ENTAO TRATAR DADOS
# modal_pl = dados['petal_length'].mode().iloc[0]
# modal_pw = dados['petal_width'].mode().iloc[0]

# %% [markdown]
# # AMPLITUDE TOTAL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bokeh.sampledata.iris import flowers as dados

# %% [markdown]
# # AMPLITUDE TOTAL

# %%
# Valores maximos - valores mínimos
dados = dados.select_dtypes(include=[np.number])
amp = dados.iloc[:,0:4].max() - dados.iloc[:,0:4].min()
amp
# Out:
# sepal_length    3.6
# sepal_width     2.4
# petal_length    5.9
# petal_width     2.4
# dtype: float64

# %% [markdown]
# **AMPLITUDE INTERQUARTÍLICA: dq = Q3 - Q1**

# %%
Q3 = np.quantile(dados['sepal_length'], 0.75)
Q2 = np.quantile(dados['sepal_length'], 0.50)
Q1 = np.quantile(dados['sepal_length'], 0.25)
amp_interquart = Q3 - Q1

# OU

amp = dados.quantile(0.75) - dados.quantile(0.25)


Q3, Q2, Q1, amp_interquart, amp
# Out:
# (6.4,
#  5.8,
#  5.1,
#  1.3000000000000007,
#  sepal_length    1.3
#  sepal_width     0.5
#  petal_length    3.5
#  petal_width     1.5
#  dtype: float64)

# %%
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# Name: 0.5, dtype: float64

# %% [markdown]
# # DESVIO MÉDIO ABSOLUTO

# %%
# dados.mean(): Calcula a média de cada coluna.
# dados.sub(dados.mean()): Subtrai a média de cada valor em suas respectivas colunas.
# abs(): Toma o valor absoluto de cada diferença.
# mean(): Calcula a média desses valores absolutos, resultando no desvio absoluto médio.
desvio_absoluto_medio = dados.sub(dados.mean()).abs().mean()
print(desvio_absoluto_medio)
# Out:
# sepal_length    0.687556
# sepal_width     0.336782
# petal_length    1.562747
# petal_width     0.658133
# dtype: float64

# %% [markdown]
# # VARIÂNCIA E DESVIO PADRÃO

# %%
# Variância Pandas
dados.var()
# Out:
# sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64

# %%
# Variância Numpy
np.var(dados)
# Out:
# sepal_length    0.681122
# sepal_width     0.188713
# petal_length    3.095503
# petal_width     0.577133
# dtype: float64

# %% [markdown]
# A diferença nos valores de variância calculados por dados.var() e np.var(dados) ocorre porque eles utilizam, por padrão, métodos ligeiramente diferentes para calcular a variância:
#
# dados.var() do Pandas: Calcula a variância amostral, usando o divisor N-1, onde N é o número de observações. Isso é conhecido como variância "correta" ou "não-viesada", pois ajusta a amostra para melhor estimar a variância da população.
#
# np.var(dados) do NumPy: Calcula a variância populacional por padrão, usando o divisor N, que é o número de observações.
#
# Para alinhar os resultados, você pode:

# %%
import numpy as np

#Fazer com que np.var() use o divisor N-1 (variância amostral):
var_amostral = np.var(dados, ddof=1)

#Calcular a variância populacional com o Pandas, se for isso que você deseja:
var_populacional = dados.var(ddof=0)

var_amostral, var_populacional
# Out:
# (sepal_length    0.685694
#  sepal_width     0.189979
#  petal_length    3.116278
#  petal_width     0.581006
#  dtype: float64,
#  sepal_length    0.681122
#  sepal_width     0.188713
#  petal_length    3.095503
#  petal_width     0.577133
#  dtype: float64)

# %% [markdown]
# **DESVIO PADRÃO**
#
# A diferença entre os valores dos desvios padrão calculados por np.std(dados) e dados.std() ocorre pelo mesmo motivo que a diferença nas variâncias: o divisor utilizado no cálculo.
#
# dados.std() do Pandas: Calcula o desvio padrão amostral, usando o divisor N-1, onde N é o número de observações. Esse ajuste é para a variância amostral, o que torna o desvio padrão "não-viesado" para amostras.
#
# np.std(dados) do NumPy: Calcula o desvio padrão populacional por padrão, usando o divisor N.

# %%
np.std(dados), dados.std()
# Out:
# (sepal_length    0.825301
#  sepal_width     0.434411
#  petal_length    1.759404
#  petal_width     0.759693
#  dtype: float64,
#  sepal_length    0.828066
#  sepal_width     0.435866
#  petal_length    1.765298
#  petal_width     0.762238
#  dtype: float64)

# %% [markdown]
# ddof=1 ajusta o cálculo para o desvio padrão amostral.
#
# ddof=0 calcula o desvio padrão populacional.

# %%
import numpy as np

# Fazer com que np.std() use o divisor N-1 (desvio padrão amostral):
desvio_padrao_amostral = np.std(dados, ddof=1)
print(desvio_padrao_amostral)

# Calcular o desvio padrão populacional com o Pandas:
desvio_padrao_populacional = dados.std(ddof=0)
print(desvio_padrao_populacional)
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64
# sepal_length    0.825301
# sepal_width     0.434411
# petal_length    1.759404
# petal_width     0.759693
# dtype: float64

# %% [markdown]
# # COEFICIENTE DE VARIAÇÃO
#  CV = std()/mean() *100

# %%
desvio_padrao_amostral = np.std(dados, ddof=1)
desvio_padrao_populacional = dados.std(ddof=0)

CV = desvio_padrao_amostral/dados.mean()*100
CV

# CV = dados.std(ddof=0)/dados.mean()*100
# CV
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# sepal_length    14.171126
# sepal_width     14.256420
# petal_length    46.974407
# petal_width     63.555114
# dtype: float64

# %%
CV2 = dados.std()/dados.mean()*100
CV2
# Out:
# sepal_length    14.171126
# sepal_width     14.256420
# petal_length    46.974407
# petal_width     63.555114
# dtype: float64

# %% [markdown]
# # MEDIDAS DE CURTOSE

# %% [markdown]
# **Leptocúrtica**: *dados **MUITO** concentrados em torno do centro (K < 0.263)*
#
# **Mesocútica**: *dados **LEVEMENTE** concentrados em torno do centro (k = 0.263)*
#
# **Platicúrtica**: *dados **POUCO** concentrados em torno do centro (K > 0.263)*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Plotagem com Boxplot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# POSIÇÃO CENTRAL: MEDIANA (Q2)
#
# DISPERSÃO: dq = Q3 - Q2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import seaborn as sns
from bokeh.sampledata.iris import flowers as dados
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
sns.boxplot(data=dados)
# Out:
# <Axes: >

# %% [markdown]
# Podemos interpretar esse gráfico como:
#
#
# *   Azul = +Simétrico
# *   Verde = +Assimétrico
# *   Amarelo = Simetria e dispersao OK, porém muitos Outliers
# *   Vermelho = Relativamente Simétrico
#
# Q1 do azul esta praticamente do mesmo tamanho q o Q3 dele, já p Q1 do verde é muito maior q o Q3.
